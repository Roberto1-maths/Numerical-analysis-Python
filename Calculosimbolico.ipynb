# %% [markdown]
# # Calculo Simbólico con Sympy

# %% [markdown]
# ### Importamos las bibliotecas necesarias

# %%
from sympy import init_session

init_session
# Out:
# <function sympy.interactive.session.init_session(ipython=None, pretty_print=True, order=None, use_unicode=None, use_latex=None, quiet=False, auto_symbols=False, auto_int_to_Integer=False, str_printer=None, pretty_printer=None, latex_printer=None, argv=[])>

# %%
init_session(use_latex=True)
# Out:
# IPython console for SymPy 1.14.0 (Python 3.11.3-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.14.0/

# %%
from sympy import symbols

# %%
# Creando simbolos
a=symbols('a')

# %%
# numeros especiales
(a+pi)**2
# Out:
#        2
# (a + π)

# %%
# La unidad imaginaria
1+2*I
# Out:
# 1 + 2⋅ⅈ

# %%
# Numero e
E**2
# Out:
#  2
# ℯ

# %%
type(a)
# Out:
# sympy.core.symbol.Symbol

# %%
# creacion de simbolos
alpha,beta=symbols('alpha,beta')

# %%
alpha
# Out:
# α

# %%
# creando simbolas reales
x,y,z,t=symbols('x,y,z,t')
x,y,z,t
# Out:
# (x, y, z, t)

# %%
x.assumptions0
# Out:
# {'commutative': True}

# %%
w=symbols('w',real=True,positive=True)

# %%
w.assumptions0
# Out:
# {'commutative': True,
#  'complex': True,
#  'extended_negative': False,
#  'extended_nonnegative': True,
#  'extended_nonpositive': False,
#  'extended_nonzero': True,
#  'extended_positive': True,
#  'extended_real': True,
#  'finite': True,
#  'hermitian': True,
#  'imaginary': False,
#  'infinite': False,
#  'negative': False,
#  'nonnegative': True,
#  'nonpositive': False,
#  'nonzero': True,
#  'positive': True,
#  'real': True,
#  'zero': False}

# %% [markdown]
# ## Expresiones
# consideremos la expresion $cos(x)^2+sen(x)^2$

# %%
cos(x)**2+sin(x)**2
# Out:
#    2         2
# sin (x) + cos (x)

# %%
#simplificando la expresion
simplify(_23)
# Out:
# {commutative: True, complex: True, extended_negative: False, extended_nonnegat ↪
#
# ↪ ive: True, extendedₙₒₙₚₒₛᵢₜᵢᵥₑ: False, extended_nonzero: True, extendedₚₒₛᵢₜ ↪
#
# ↪ ᵢᵥₑ: True, extendedᵣₑₐₗ: True, finite: True, hermitian: True, imaginary: Fal ↪
#
# ↪ se, infinite: False, negative: False, nonnegative: True, nonpositive: False, ↪
#
# ↪  nonzero: True, positive: True, real: True, zero: False}

# %%
sqrt(z**2)
# Out:
#    ____
#   ╱  2
# ╲╱  z

# %%
simplify(27)
# Out:
# 27

# %%
y=symbols('y',real=True)
simplify(sqrt(y**2))
# Out:
# │y│

# %% [markdown]
# ### substituir varaias variables

# %%
(sin(x)**2+cos(y)**2).subs({x:1+z,y:1-z})
# Out:
#    2             2
# sin (z + 1) + cos (z - 1)

# %% [markdown]
# ### substituir por funciones

# %%
sin(x).replace(sin,exp)
# Out:
#  x
# ℯ

# %% [markdown]
# ### Particularizar en un valor

# %%
(tan(x)+3*x).subs(x,pi/4)
# Out:
#     3⋅π
# 1 + ───
#      4

# %% [markdown]
# ### Si se quiere el valor numérico

# %%
_44.evalf()
# Out:
# 3.35619449019234

# %%
N(_44)
# Out:
# 3.35619449019234

# %% [markdown]
# ## Derivadas e Integrales

# %%
expr=cos(x)
expr
# obtenemos la primera derivada
expr.diff(x)
# Out:
# -sin(x)

# %% [markdown]
# #### La derivada cuarta

# %%
expr.diff(x,4)
# Out:
# cos(x)

# %% [markdown]
# #### varias variables

# %%
expr=y*exp(2*x)+y/(x**2+y**3)
expr
# Out:
#    2⋅x      y
# y⋅ℯ    + ───────
#           2    3
#          x  + y

# %%
expr.diff(x,2,y,3)
# Out:
#      ⎛        2  6        2  3         2           6          3     ⎞
#      ⎜  1080⋅x ⋅y    648⋅x ⋅y      48⋅x       108⋅y       81⋅y      ⎟
# 12⋅y⋅⎜- ────────── + ────────── - ─────── + ────────── - ─────── + 8⎟
#      ⎜           3            2    2    3            2    2    3    ⎟
#      ⎜  ⎛ 2    3⎞    ⎛ 2    3⎞    x  + y    ⎛ 2    3⎞    x  + y     ⎟
#      ⎝  ⎝x  + y ⎠    ⎝x  + y ⎠              ⎝x  + y ⎠               ⎠
# ─────────────────────────────────────────────────────────────────────
#                                        3
#                               ⎛ 2    3⎞
#                               ⎝x  + y ⎠

# %% [markdown]
# #### Dejaral indicada

# %%
Derivative(expr,y)
# Out:
# ∂ ⎛   2⋅x      y   ⎞
# ──⎜y⋅ℯ    + ───────⎟
# ∂y⎜          2    3⎟
#   ⎝         x  + y ⎠

# %% [markdown]
# ### Integración
# $$\int{cos(x)^2dx}$$

# %% [markdown]
# $$\int\frac{1}{sin(x)}dx$$

# %% [markdown]
# $$ \int\frac{1}{(x^2+a^2)^3}dx$$

# %%
(1/(x**2+a**2)**3)

# %%
integrate(cos(x)**2,x)
# Out:
# x   sin(x)⋅cos(x)
# ─ + ─────────────
# 2         2

# %%
(1/sin(x)).integrate()
# Out:
# log(cos(x) - 1)   log(cos(x) + 1)
# ─────────────── - ───────────────
#        2                 2

# %%
(1/(x**2+a**2)**3)
# Out:
#     1
# ──────────
#          3
# ⎛ 2    2⎞
# ⎝a  + x ⎠

# %%
integrate(1/(x**2+a**2)**3,x)
# Out:
#                               3⋅ⅈ⋅log(-ⅈ⋅a + x)   3⋅ⅈ⋅log(ⅈ⋅a + x)
#          2        3         - ───────────────── + ────────────────
#       5⋅a ⋅x + 3⋅x                    16                 16
# ───────────────────────── + ──────────────────────────────────────
#    8       6  2      4  4                      5
# 8⋅a  + 16⋅a ⋅x  + 8⋅a ⋅x                      a
